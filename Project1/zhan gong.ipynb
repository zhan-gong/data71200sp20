# %%
import numpy as np
import pandas as pd
import scipy as sp
import sklearn

# %%
wine_data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data',  header = None)

# %%
feature_names = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

# %%
wine_data.columns = feature_names
wine_data
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
data = wine_data.drop(columns = ['Class'])

# %%
target = wine_data['Class']

# %%
target
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Class, Length: 178, dtype: int64

# %%
data
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data,target, random_state = 0)

# %%
print("X_train shape: {}".format(X_train.shape))
print("y_train shape: {}".format(y_train.shape))
# Out:
# X_train shape: (133, 13)
# y_train shape: (133,)

# %%
print("X_test shape: {}".format(X_test.shape))
print("y_test shape: {}".format(y_test.shape))
# Out:
# X_test shape: (45, 13)
# y_test shape: (45,)

# %%
X_train.info()
X_train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133 entries, 19 to 172
# Data columns (total 13 columns):
# Alcohol                         133 non-null float64
# Malic acid                      133 non-null float64
# Ash                             133 non-null float64
# Alcalinity of ash               133 non-null float64
# Magnesium                       133 non-null int64
# Total phenols                   133 non-null float64
# Flavanoids                      133 non-null float64
# Nonflavanoid phenols            133 non-null float64
# Proanthocyanins                 133 non-null float64
# Color intensity                 133 non-null float64
# Hue                             133 non-null float64
# OD280/OD315 of diluted wines    133 non-null float64
# Proline                         133 non-null int64
# dtypes: float64(11), int64(2)
# memory usage: 14.5 KB
#           Alcohol  Malic acid         Ash  Alcalinity of ash   Magnesium  \
# ...

# %%
print(X_train.isnull().sum())
# Out:
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
X_train.hist(bins=30, figsize=(20,15))
plt.show()

# %%
pd.plotting.scatter_matrix(X_train,figsize=(35,15), alpha=0.2)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002595DCE7BC8>,
# ...
#       dtype=object)

# %%
Test = X_train[['Ash','Hue']]

# %%
squaring = Test**2

# %%
squaring.hist(bins=30)
plt.show()

# %%
pd.plotting.scatter_matrix(squaring,figsize=(35,15), alpha=1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025968C1C1C8>,
# ...
#       dtype=object)

# %%
cubing = Test**3

# %%
cubing.hist(bins=30)
plt.show()

# %%
pd.plotting.scatter_matrix(cubing,figsize=(35,15), alpha=1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002596A5B6A48>,
# ...
#       dtype=object)

# %%
import math
log = np.log(Test)

# %%
log.hist(bins=30)
plt.show()

# %%
pd.plotting.scatter_matrix(log,figsize=(35,15),alpha=1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002596D414988>,
# ...
#       dtype=object)

# %%
exp = np.exp(Test)

# %%
exp.hist(bins=30)
plt.show()

# %%
pd.plotting.scatter_matrix(exp,figsize=(35,15), alpha=1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000223F7200FC8>,
# ...
#       dtype=object)
